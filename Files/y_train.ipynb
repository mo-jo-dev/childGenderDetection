# %%
import pandas as pd

# %%
df = pd.read_csv("path_train.txt", header = None)
df.columns = ['Name']
df
# Out:
#                                          Name
# 0           train_pfstar/001f12bh_digits1.wav
# 1           train_pfstar/001f12bh_digits6.wav
# 2            train_pfstar/001f12bh_list_1.wav
# 3         train_pfstar/001f12bh_list_ph01.wav
# 4         train_pfstar/001f12bh_list_ph06.wav
# ..                                        ...
# 851       train_pfstar/248f08sp_list_ph13.wav
# 852       train_pfstar/248f08sp_list_ph18.wav
# 853  train_pfstar/248f08sp_sentences3or8a.wav
# 854        train_pfstar/248f08sp_w_list3a.wav
# 855        train_pfstar/248f08sp_w_list3b.wav
#
# [856 rows x 1 columns]

# %%
x = df.Name.str[16]
df['Gender'] = x
df
# Out:
#                                          Name Gender
# 0           train_pfstar/001f12bh_digits1.wav      f
# 1           train_pfstar/001f12bh_digits6.wav      f
# 2            train_pfstar/001f12bh_list_1.wav      f
# 3         train_pfstar/001f12bh_list_ph01.wav      f
# 4         train_pfstar/001f12bh_list_ph06.wav      f
# ..                                        ...    ...
# 851       train_pfstar/248f08sp_list_ph13.wav      f
# 852       train_pfstar/248f08sp_list_ph18.wav      f
# 853  train_pfstar/248f08sp_sentences3or8a.wav      f
# 854        train_pfstar/248f08sp_w_list3a.wav      f
# 855        train_pfstar/248f08sp_w_list3b.wav      f
#
# [856 rows x 2 columns]

# %%
df.to_csv("y_train.csv", index = False)
