# %%
import librosa
from tqdm import tqdm
import numpy as np
import pandas as pd

# %%
def feature_extraction(file_path):
    y, sample_rate = librosa.load(file_path, res_type = "soxr_hq")
    mfcc = np.mean(librosa.feature.mfcc(y = y, sr = sample_rate, n_mfcc = 39).T, axis = 0)

    return mfcc

# %%
features = {}

# %%
with open("path_test.txt", "r") as file:
    audio_paths = file.readlines()

audio_paths = [ path.strip() for path in audio_paths ]

# %%
for path in tqdm(audio_paths):
    features[path] = feature_extraction(path)
# Out:
# 100%|██████████| 129/129 [00:04<00:00, 29.53it/s]

# %%
df = pd.DataFrame.from_dict(features.values())
df
# Out:
#              0          1          2          3          4          5   \
# 0   -295.443909  49.006618 -33.630814  55.130447 -30.433764  25.700630
# 1   -414.080322  40.497242 -12.854951  18.804569 -11.105615   1.522901
# 2   -448.822815  39.273724  -9.414446  17.085396 -13.178941   2.997528
# 3   -315.118500  37.206505 -30.080963  40.615547 -31.191830  18.042690
# 4   -260.324707  49.710228 -40.616920  49.079716 -39.089714  21.955444
# ..          ...        ...        ...        ...        ...        ...
# 124 -290.292572  61.222385 -31.498934  48.976440 -27.555397  10.776296
# 125 -373.212463  48.029930 -22.612448  43.627003 -22.947264   9.920604
# 126 -405.776733  56.336544 -29.051123  42.896156 -23.369392  10.976414
# 127 -317.021149  63.160309 -34.149284  39.691917 -24.462332  12.946914
# 128 -335.065125  60.437813 -30.789900  41.573650 -21.145229  13.275164
#
#             6          7          8         9   ...         29        30  \
# 0   -19.513330   8.232924 -11.544922  2.850244  ...   8.301552  6.795958
# 1    -3.025048   0.361386   0.901961 -1.174378  ...   0.009065 -0.254289
# 2    -2.402884  -0.984633   3.086136 -0.834018  ...  -0.239110 -0.467611
# 3   -17.667921  11.238570  -8.382076  0.104715  ...   7.559400  4.125650
# 4   -22.461029  12.427060 -11.052589  1.987215  ...  10.147694  9.314344
# ..         ...        ...        ...       ...  ...        ...       ...
# 124  -2.776672   4.704957   3.805642  2.112067  ...   4.396727  0.647801
# 125  -1.975398   3.563087   4.732645  2.169028  ...   1.729083 -0.155651
# 126  -2.403592   5.286330   6.058531  1.858445  ...   1.933333  0.110041
# 127  -1.576306   2.305114   7.836551  0.758541  ...   2.791638 -0.667424
# 128  -1.067898   5.737640   5.794109  1.966861  ...   3.589772  0.664649
#
#            31        32        33        34        35        36        37  \
# 0    7.103918  7.394035  2.681389  8.337363  0.341784  6.470315  0.656670
# 1   -0.591698  0.686029 -0.683398 -0.262996 -2.091954 -0.053971 -0.199228
# 2   -0.880765  0.279056 -1.467867 -0.442762 -1.912249 -0.540331 -0.520568
# 3    0.458196  0.853175 -2.511544  1.070528 -3.017412  2.042986 -3.537422
# 4    4.888262  5.048138 -2.303378  1.424387 -3.320233  2.768922 -2.723704
# ..        ...       ...       ...       ...       ...       ...       ...
# 124  0.170710  1.478228 -1.246344  1.022299 -2.251168  0.994034 -2.058969
# 125  0.573155  1.391546 -1.415853  0.580986 -1.589047  1.431176 -0.972602
# 126  0.371301  1.122124 -1.213980  0.718721 -1.817362  1.106438 -1.297586
# 127  0.518487  2.066391 -1.111790  0.625487 -2.124908  1.075285 -0.796571
# 128  0.016554  1.566538 -0.979031  1.360863 -1.327918  1.016242 -0.653638
#
#            38
# 0    3.807948
# 1    0.071490
# 2   -0.766459
# 3   -1.789025
# 4   -0.082533
# ..        ...
# 124 -0.174600
# 125  1.372133
# 126  1.198736
# 127  0.246308
# 128  1.428013
#
# [129 rows x 39 columns]

# %%
df.to_csv('X_Test.csv', index = False)
