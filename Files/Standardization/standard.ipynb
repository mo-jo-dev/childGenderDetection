# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df_train = pd.read_csv('../X_Train.csv')
df_test = pd.read_csv('../X_Test.csv')

# %%
df_train.head()
# Out:
#            0          1          2          3          4          5  \
# 0 -393.25937  47.211365 -14.840610  48.223183 -12.648447  12.918578
# 1 -301.02374  55.178350 -33.070267  60.668667 -27.534761  21.097240
# 2 -340.74554  55.172844 -28.853863  56.792590 -20.615953  16.453169
# 3 -301.35336  57.852460 -32.282894  58.409010 -21.080715  19.951340
# 4 -312.69220  66.862380 -37.124230  60.418377 -25.323230  18.759283
#
#            6          7         8         9  ...         29        30  \
# 0  -8.701591   8.800138  1.150031 -1.520719  ...   5.719014  7.661323
# 1 -17.485130  10.804612 -2.711287 -0.730897  ...   7.210642  7.889643
# 2 -15.359990  11.006892 -1.211429  1.864681  ...   8.118001  8.559962
# 3 -15.906841  10.579597 -0.819382  1.031019  ...   7.574814  6.503914
# 4 -18.305700  10.565392 -1.530734  1.156553  ...  10.431557  9.775954
#
#           31         32        33         34        35        36        37  \
# ...

# %%
df_test.head()
# Out:
#            0          1          2          3          4          5  \
# 0 -295.44390  49.006620 -33.630814  55.130447 -30.433764  25.700630
# 1 -414.08032  40.497242 -12.854951  18.804570 -11.105615   1.522901
# 2 -448.82280  39.273724  -9.414446  17.085396 -13.178941   2.997528
# 3 -315.11850  37.206505 -30.080963  40.615547 -31.191830  18.042690
# 4 -260.32470  49.710228 -40.616920  49.079716 -39.089714  21.955444
#
#            6          7          8         9  ...         29        30  \
# 0 -19.513330   8.232924 -11.544922  2.850244  ...   8.301552  6.795958
# 1  -3.025048   0.361386   0.901961 -1.174378  ...   0.009065 -0.254289
# 2  -2.402884  -0.984633   3.086136 -0.834018  ...  -0.239110 -0.467611
# 3 -17.667921  11.238570  -8.382076  0.104715  ...   7.559400  4.125650
# 4 -22.461030  12.427060 -11.052589  1.987215  ...  10.147694  9.314344
#
#          31        32        33        34        35        36        37  \
# ...

# %%
scaler = StandardScaler()
scaler.fit(df_train)
scaled_data_train = scaler.transform(df_train)

# %%
scaler = StandardScaler()
scaler.fit(df_test)
scaled_data_test = scaler.transform(df_test)

# %%
scaled_data_train_df = pd.DataFrame(scaled_data_train)
scaled_data_train_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.668553 -1.297257  0.971568  0.475563  0.761505  0.150822 -0.050301
# 1  0.375962 -0.737954 -0.477299  1.796089 -0.880277  1.412751 -1.445570
# 2 -0.504520 -0.738341 -0.142185  1.384818 -0.117215  0.696192 -1.107991
# 3  0.368656 -0.550225 -0.414720  1.556328 -0.168473  1.235944 -1.194858
# 4  0.117317  0.082294 -0.799503  1.769532 -0.636372  1.052015 -1.575918
#
#          7         8         9   ...        29        30        31        32  \
# 0  0.658133  0.410332 -1.445036  ... -0.236296  0.517192  2.258106  2.153228
# 1  1.103039 -0.563930 -1.153701  ...  0.266311  0.597057  2.200927  2.615331
# 2  1.147937 -0.185496 -0.196293  ...  0.572048  0.831532  1.552937  1.073207
# 3  1.053096 -0.086577 -0.503798  ...  0.389020  0.112335  1.276183  0.987278
# 4  1.049943 -0.266061 -0.457494  ...  1.351606  1.256882  1.811191  1.082727
#
#          33        34        35        36        37        38
# ...

# %%
scaled_data_test_df = pd.DataFrame(scaled_data_test)
scaled_data_test_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.458850 -0.829371 -0.291432  1.374824 -0.715761  1.972980 -1.553072
# 1 -1.995583 -1.401461  1.323905 -2.622218  1.294457 -1.584414  1.139461
# 2 -2.714360 -1.483719  1.591406 -2.811384  1.078821 -1.367445  1.241061
# 3  0.051808 -1.622699 -0.015429 -0.222292 -0.794603  0.846228 -1.251717
# 4  1.185420 -0.782067 -0.834607  0.709045 -1.616020  1.421932 -2.034431
#
#          7         8         9   ...        29        30        31        32  \
# 0  0.503142 -2.341967  0.459910  ...  0.697867  0.456045  0.990348  0.868418
# 1 -1.117208  0.467971 -0.975320  ... -1.809591 -1.493165 -1.016568 -1.148028
# 2 -1.394285  0.961058 -0.853943  ... -1.884634 -1.552143 -1.091953 -1.270365
# 3  1.121852 -1.627941 -0.519179  ...  0.473457 -0.282225 -0.742769 -1.097783
# 4  1.366501 -2.230820  0.152144  ...  1.256098  1.152314  0.412534  0.163235
#
#          33        34        35        36        37        38
# ...

# %%
scaled_data_train_df.to_csv('X_Train.csv', index = 0)
scaled_data_test_df.to_csv('X_Test.csv', index = 0)
